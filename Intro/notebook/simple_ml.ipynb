# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\mkcak\\OneDrive - Hochschule Luzern\\Documents\\Learning Projects\\Hands-on Machine Learning\\Intro\\notebook'

# %%
os.chdir(r"C:\Users\mkcak\OneDrive - Hochschule Luzern\Documents\Learning Projects\Hands-on Machine Learning\Intro\data")
os.getcwd()
# Out:
# 'C:\\Users\\mkcak\\OneDrive - Hochschule Luzern\\Documents\\Learning Projects\\Hands-on Machine Learning\\Intro\\data'

# %%
lifesat = pd.read_excel("happiness.xlsx")

# %%
lifesat.dropna(inplace=True)

# %%
lifesat.head()
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008     3.723590            7.370100        0.450662
# 1  Afghanistan  2009     4.401778            7.539972        0.552308
# 2  Afghanistan  2010     4.758381            7.646709        0.539075
# 3  Afghanistan  2011     3.831719            7.619532        0.521104
# 4  Afghanistan  2012     3.782938            7.705479        0.520637
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         50.799999                      0.718114    0.167640
# 1                         51.200001                      0.678896    0.190099
# 2                         51.599998                      0.600127    0.120590
# 3                         51.919998                      0.495901    0.162427
# 4                         52.240002                      0.530935    0.236032
#
#    Perceptions of corruption  Positive affect  Negative affect
# ...

# %%
X = lifesat[["Log GDP per capita"]].values

# %%
X
# Out:
# array([[7.37009954],
#        [7.53997231],
#        [7.64670897],
#        ...,
#        [8.04879761],
#        [7.95013189],
#        [7.82875681]])

# %%
y = lifesat[["Life Ladder"]].values

# %%
lifesat.plot(kind="scatter", grid=True,
             x ="Log GDP per capita", y= "Life Ladder" )
plt.show()

# %%
model = LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
X_new = [[37]]

# %%
model.predict(X_new)
# Out:
# array([[26.97907491]])
